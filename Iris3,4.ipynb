# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
import seaborn as sns
import pandas as pd

# %%
iris = datasets.load_iris()

# %%
X = iris.data[iris.target!=0, :4]
y = iris.target[iris.target!=0]

# %%
iris_frame = pd.DataFrame(iris.data,columns = iris.feature_names)
iris_frame['target'] = iris.target
# Для наглядности добавляем столбец с сортами: 
iris_frame['name'] = iris_frame['target'].map(lambda x : iris.target_names[x])
# Смотрим, что получилось:
iris_frame
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target       name
# ...

# %%
#X = iris_frame.loc[:, 4]
#y = iris_frame.loc[iris_frame['target'] == target_name,feature_name]
X = iris.data[iris.target!=0, :4]
y = iris.target[iris.target!=0]
model = LinearDiscriminantAnalysis()
#X_lda=model.fit_transform(X,y)


#X = scaler.fit_transform(ab_data.X)
#lda = LinearDiscriminantAnalysis(n_components=2)
model.fit_transform(X,y)
lda_s_ab = model.predict(X)
X = pd.DataFrame(X)
X["name"] = pd.DataFrame(lda_s_ab)
sns.pairplot(X, hue="name")
#plt.savefig('lda_ab_pp.png')
    # plt.show()
#plt.close()
# pd.DataFrame(lda_s_ab)

# %%
iris = pd.read_csv(r'C:\Users\Darya\Downloads\iris.data', header=None)
iris.columns=['sepal length','sepal width', 'petal length', 'petal width', 'class']
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
feature = data.data[data.target!=0]
target = data.target[data.target!=0]

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from matplotlib import pylab
from pylab import *

data = datasets.load_iris()

feature_names = data['feature_names']

sepal_length = feature[:, 0:1]
sepal_width	= feature[:, 1:2]
petal_length = feature[:, 2:3]
petal_width = feature[:, 3:4]


sl_miny, sl_maxy = sepal_length.min()-1, sepal_length.max()+1
sw_miny, sw_maxy = sepal_width.min()-1, sepal_width.max()+1
pl_miny, pl_maxy = petal_length.min()-1, petal_length.max()+1

sw_minx, sw_maxx = sepal_width.min()-1, sepal_width.max()+1
pl_minx, pl_maxx = petal_length.min()-1, petal_length.max()+1
pw_minx, pw_maxx = petal_width.min()-1, petal_width.max()+1

s = 0.02


xx1, yy1 = np.meshgrid(np.arange(sw_minx, sw_maxx, s), 
                     np.arange(sl_miny, sl_maxy, s))
xx2, yy2 = np.meshgrid(np.arange(pl_minx, pl_maxx, s),
                     np.arange(sl_miny, sl_maxy, s))
xx3, yy3 = np.meshgrid(np.arange(pw_minx, pw_maxx, s),
                     np.arange(sl_miny, sl_maxy, s))
xx4, yy4 = np.meshgrid(np.arange(pl_minx, pl_maxx, s),
                     np.arange(sw_miny, sw_maxy, s))
xx5, yy5 = np.meshgrid(np.arange(pw_minx, pw_maxx, s),
                     np.arange(sw_miny, sw_maxy, s))
xx6, yy6 = np.meshgrid(np.arange(pw_minx, pw_maxx, s),
                     np.arange(pl_miny, pl_maxy, s))

XX = [xx1, xx2, xx3, xx4, xx5, xx6]
YY = [yy1, yy2, yy3, yy4, yy5, yy6]

X1 = np.concatenate((sepal_length, sepal_width), axis=1)
X2 = np.concatenate((sepal_length, petal_length), axis=1)
X3 = np.concatenate((sepal_length, petal_width), axis=1)
X4 = np.concatenate((sepal_width, petal_length), axis=1)
X5 = np.concatenate((sepal_width, petal_width), axis=1)
X6 = np.concatenate((petal_length, petal_width), axis=1)


Y = target   


LDA1 = LinearDiscriminantAnalysis(store_covariance=True).fit(X1,Y)
LDA2 = LinearDiscriminantAnalysis(store_covariance=True).fit(X2,Y)
LDA3 = LinearDiscriminantAnalysis(store_covariance=True).fit(X3,Y)
LDA4 = LinearDiscriminantAnalysis(store_covariance=True).fit(X4,Y)
LDA5 = LinearDiscriminantAnalysis(store_covariance=True).fit(X5,Y)
LDA6 = LinearDiscriminantAnalysis(store_covariance=True).fit(X6,Y)

models = [LDA1, LDA2, LDA3, LDA4, LDA5, LDA6]


pylab.rcParams['figure.figsize'] = (15, 10)

m, c  = "vox", "rgb"
p = [(0,1),(0,2),(0,3),(1,2),(1,3),(2,3)]



for i,(x,y), clf, xx, yy in zip([0,1,2,3,4,5],p, models, XX, YY):
    plt.subplot(2,3,i+1)
    Z = clf.predict(np.c_[yy.ravel(), xx.ravel()])
    Z = Z.reshape(yy.shape)
    plt.contourf(yy, xx, Z,  alpha=0.3)
    for cls, marker, clr in zip([0,1,2], m, c):
        plt.scatter(feature[target == cls,x], feature[target == cls,y], marker=marker, s=20, edgecolors='r')

    plt.ylim(xx.min(), xx.max())
    plt.xlim(yy.min(), yy.max())
    plt.xlabel(feature_names[x])
    plt.ylabel(feature_names[y])
# Out:
# C:\Users\Darya\AppData\Local\Temp/ipykernel_3032/2127788845.py:77: UserWarning: You passed a edgecolor/edgecolors ('r') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(feature[target == cls,x], feature[target == cls,y], marker=marker, s=20, edgecolors='r')
# C:\Users\Darya\AppData\Local\Temp/ipykernel_3032/2127788845.py:77: UserWarning: You passed a edgecolor/edgecolors ('r') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(feature[target == cls,x], feature[target == cls,y], marker=marker, s=20, edgecolors='r')
# C:\Users\Darya\AppData\Local\Temp/ipykernel_3032/2127788845.py:77: UserWarning: You passed a edgecolor/edgecolors ('r') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# ...

# %%
import pandas as pd
import numpy as np
from numpy.linalg import multi_dot
from numpy.linalg import inv
from numpy.linalg import det
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

iris2 = pd.DataFrame(iris, columns=['sepal width', 'sepal length', 'class'])


X =  iris2.drop(['class'], axis=1)
y = iris2['class']

class qda():
    
    def __init__(self, x_train, y_train): 
        
        self.x_train = x_train               
        self.y_train = y_train               
    
    def get_class_data(self):          
        
        self.class_data = {}
        for cls in self.y_train.unique():
            idx = self.y_train[self.y_train == cls].index
            self.class_data[cls] = self.x_train.loc[idx, :]
    
    def get_prior(self):                 
                                         
        self.class_prior = {}
        for cls in self.y_train.unique():
            self.class_prior[cls] = len(self.y_train[self.y_train == cls])/len(self.y_train)
    
    def get_class_mean(self):          
                                       
        self.class_mean = {}
        for cls in self.class_data:
            self.class_mean[cls] = np.array(self.class_data[cls].mean())
        
    def get_class_covariance(self):
        
        self.class_cov = {}
        self.class_cov_det = {}
        self.class_cov_inv = {}
        for cls in self.class_data:
            self.class_cov[cls] = np.cov(np.array(self.class_data[cls]).T)  
            self.class_cov_det[cls] = det(self.class_cov[cls])              
            self.class_cov_inv[cls] = inv(self.class_cov[cls])              

    def predict(self, x):      
        
        pos = [((-1/2)*(x - self.class_mean[cls]).T @ (self.class_cov_inv[cls]) @ (x - self.class_mean[cls])) + (-1/2)*np.log(self.class_cov_det[cls]) + np.log(self.class_prior[cls])
               for cls in self.class_data]
        y_pred = np.argmax(pos)
        
        return y_pred
    
    def plot_decision_boundary(self):
        
        min1, max1 = self.x_train.iloc[:,0].min() - 1, self.x_train.iloc[:,0].max() + 1
        min2, max2 = self.x_train.iloc[:,1].min() - 1, self.x_train.iloc[:,1].max() + 1
        
        x1grid = np.arange(min1, max1, 0.01)
        x2grid = np.arange(min2, max2, 0.01)
        xx, yy = np.meshgrid(x1grid, x2grid)
        r1, r2 = xx.flatten(), yy.flatten()
        r1, r2 = r1.reshape((len(r1), 1)), r2.reshape((len(r2), 1))
        grid = np.hstack((r1,r2))


        yhat = [self.predict(g) for g in grid]
        zz = np.array(yhat).reshape(xx.shape)
        
        colors = ['r','g', 'b']
        target_names = ['Iris-setosa','Iris-versicolor', 'Iris-virginica']
        markers = ['s','s', 's']

        plt.figure(figsize=(10,8))
        plt.contourf(xx, yy, zz, alpha=0.8)
        for cls, color, mark, target_name in zip(self.class_data, colors,markers, target_names):
            idx = self.y_train[self.y_train == cls].index
            plt.scatter(self.x_train.iloc[idx, 0], self.x_train.iloc[idx, 1], alpha=0.8, color=color, label=target_name, marker=mark)
            plt.legend(loc="best", shadow=False, scatterpoints=1)
            plt.title("QDA") 

    def train(self):
        
        self.get_class_data()
        self.get_prior()
        self.get_class_mean()
        self.get_class_covariance()

        
qda = qda(X, y)
qda.train()
qda.plot_decision_boundary()
